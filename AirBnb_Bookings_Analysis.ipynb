# %% [markdown]
# <a href="https://colab.research.google.com/github/Amit6124/EDA-AIRBNB-BOOKING-ANAYLSIS/blob/main/AirBnb_Bookings_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Image](https://user-images.githubusercontent.com/123977645/215566852-0b098d9b-f54a-4106-84a8-b72379f85e99.png)

# %% [markdown]
# # **Project Name**    -  **AirBnb Bookings Analysis**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Amit Singh

# %% [markdown]
# # **Project Summary**

# %% [markdown]
# **BUSINESS PROBLEM OVERVIEW**
#
#
# # Founded in 2008, Airbnb is a growing and popular alternative to traditional lodging. It is essentially an open market where as a host, you can list a spare room, entire apartment or home for prospective travelers to book and use as a domicile during a trip. Currently there are no free resources for hosts to use when trying to price their Airbnb listing on the open market. Since the amount of listings for Airbnb rentals has exploded over the last several years, being able to competitively price your rental space is a must in order to maintain a high booking rate and rate of return for your property. My goal is to develop a tool for hosts to use to gain insight on how to appropriately price their Airbnb rental space in the market they reside in.

# %% [markdown]
# # **Github Link** - https://github.com/Amit6124/EDA-AIRBNB-BOOKING-ANAYLSIS

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present a more unique, personalized way of experiencing the world. Today, Airbnb has become one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data that can be analyzed and used for security, business decisions, understanding of customers' and providers' (hosts') behavior and performance on the platform, guiding marketing initiatives, implementation of innovative additional services, and much more. This dataset has around 49,000 observations with 16 columns, and it is a mix of categorical and numeric values.

# %% [markdown]
# # **Explore** and analyze the data to discover key understandings and aspects affecting airbnb bookings in NYC

# %% [markdown]
# * What can we learn about different hosts and areas?
#
# * What can we learn from predictions? (ex: locations, prices, reviews, etc)
#
# * Which hosts are the busiest and why?
#
# * Is there any noticeable difference of traffic among different areas and what could be the reason for it?

# %% [markdown]
# # **General Guidelines** : -
#
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# # INITIAL SETTINGS AND LOADING OF DATA OF AIRBNB
#
# ---

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %% [markdown]
# * MOUNT THE DATA FROM DRIVE

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# * LOADING DATA FROM THE OFFLINE FILES

# %%
# Importing the dataset
path='/content/drive/MyDrive/Airbnb NYC 2019.csv'
df = pd.read_csv(path)

# %% [markdown]
# ### Dataset First View

# %% [markdown]
# * INSPECTING OF DATA

# %%
# Dataset First 3 rows
df.head(3)
# Out:
#      id                                 name  host_id  host_name  \
# 0  2539   Clean & quiet apt home by the park     2787       John
# 1  2595                Skylit Midtown Castle     2845   Jennifer
# 2  3647  THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
# 2    150               3                  0         NaN                NaN
#
#    calculated_host_listings_count  availability_365
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns 
df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ***Observation : From this we got 48895 Row & 16 Columns from the given dataset***

# %%
print(df.columns)
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# ### Dataset Information

# %% [markdown]
# * OBTAINING IMPORTANT INFORMATION

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(df[df.duplicated()])
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum())
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# * **OBSERVATION FROM THE DATA**
#
#
# 1>Columns like name ,host_name ,last_review and review_per_month have missing   values .
#
# 2>Columns like host_name ,name and last_reviews are not important , therefore we can drop these columns.
#
# 3>last_review and reviews_per_month columns have NaN and they are connected ,hence when the date is missing in last_review the values in review_per_month is also missing .

# %% [markdown]
# # Visualizing the missing values
# # Checking Null Value by plotting Heatmap
#
# ---

# %%
sns.heatmap(df.isnull(), cbar=False )

# %% [markdown]
# Observation: The heatmap visualizes the presence of missing values (null values) in the dataframe.  The heatmap provides a quick and easy way to see which columns or rows have missing values and to what extent. This information can then be used to decide on the best approach for handling the missing values, such as imputing them or removing them.

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# With the given data, our first step is to identify all the variables and find out the relationship between them. Our first sub-problem is that first focus on its physical features and its facilities and find out the relationship between top listings with prices. We mainly focused on the listing's room type, the property type, price, host, location, and reviews.
#
# id: all properties have a unique id by
# which we tried to find unique properties.
#
# Host_id: all the hosts have a unique id
# by which we tried to find unique number of hosts, their maximum number of listings, most popular host and their charges.
#
# Neighbourhood_group &
# neighborhood: by this, we tried to find out which neighborhood group has the maximum number of properties, which one is the most popular, which one is the most expensive place to live.
#
# Room_type: In the given data, there
# are three types of rooms are available that is private, shared, and entire home and we tried to find out which types of rooms are the most popular and most expensive.
#
# Number_of_reviews: by this, we tried
# to find out which property has the best service and which host provides the best service.
#
# Availability_365: by this, we tried
# to find the availability of the property

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# Each listing had 16 attributes and 48895 listings in New York City
#
#
# *  Id
#
# * Name
#
# * Host Id
#
# * Host Name
#
# * Neighbourhood Group - i.e. location
#
# * Neighbourhood
#
# * Latitude
#
# * Longitude
#
# * Room Type - i.e.
#
#    Entire home/apartment
#
#    Private Room
#
#    Shared Room
#
# * Price
#
# * Minimum Nights
#
# * Number of Reviews
#
#
# * Reviews Per Month
#
# * Calculated Host Listings Count
#
# * Availability (Days)

# %%
# Dataset Describe
df.describe(include='all')
# Out:
#                   id            name       host_id host_name  \
# count   4.889500e+04           48879  4.889500e+04     48874
# unique           NaN           47905           NaN     11452
# top              NaN  Hillside Hotel           NaN   Michael
# freq             NaN              18           NaN       417
# mean    1.901714e+07             NaN  6.762001e+07       NaN
# std     1.098311e+07             NaN  7.861097e+07       NaN
# min     2.539000e+03             NaN  2.438000e+03       NaN
# 25%     9.471945e+06             NaN  7.822033e+06       NaN
# 50%     1.967728e+07             NaN  3.079382e+07       NaN
# 75%     2.915218e+07             NaN  1.074344e+08       NaN
# max     3.648724e+07             NaN  2.743213e+08       NaN
#
#        neighbourhood_group neighbourhood      latitude     longitude  \
# count                48895         48895  48895.000000  48895.000000
# unique                   5           221           NaN           NaN
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ![EDA_Air_Bnb_Bookings_Analysis_73e51f569a.png](data:image/png;base64,...)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns.tolist():
  print("No. of unique values in ",i,"is",df[i].nunique(),".")
# Out:
# No. of unique values in  id is 48895 .
# No. of unique values in  name is 47905 .
# No. of unique values in  host_id is 37457 .
# No. of unique values in  host_name is 11452 .
# No. of unique values in  neighbourhood_group is 5 .
# No. of unique values in  neighbourhood is 221 .
# No. of unique values in  latitude is 19048 .
# No. of unique values in  longitude is 14718 .
# No. of unique values in  room_type is 3 .
# No. of unique values in  price is 674 .
# No. of unique values in  minimum_nights is 109 .
# No. of unique values in  number_of_reviews is 394 .
# No. of unique values in  last_review is 1764 .
# No. of unique values in  reviews_per_month is 937 .
# No. of unique values in  calculated_host_listings_count is 47 .
# No. of unique values in  availability_365 is 366 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# * ### Data Wrangling Code

# %%
#dropping columns that are not significant for our data analysis
df.drop(['id','host_name','last_review'], axis=1, inplace=True)

# %%
df.head(10)
# Out:
#                                                name  host_id  \
# 0                Clean & quiet apt home by the park     2787
# 1                             Skylit Midtown Castle     2845
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3                   Cozy Entire Floor of Brownstone     4869
# 4  Entire Apt: Spacious Studio/Loft by central park     7192
# 5         Large Cozy 1 BR Apartment In Midtown East     7322
# 6                                   BlissArtsSpace!     7356
# 7                  Large Furnished Room Near B'way      8967
# 8                Cozy Clean Guest Room - Family Apt     7490
# 9                Cute & Cozy Lower East Side 1 bdrm     7549
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0            Brooklyn          Kensington  40.64749  -73.97237
# 1           Manhattan             Midtown  40.75362  -73.98377
# 2           Manhattan              Harlem  40.80902  -73.94190
# ...

# %% [markdown]
# * Handling NULL values
#
#
# ---

# %%
print(df.isnull().sum())
#replacing all NaN values in 'reviews_per_month' with 0
df.fillna({'reviews_per_month':0}, inplace=True)
# Out:
# name                                 16
# host_id                               0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# * Removes all the rows from the dataframe (df) that contain at least one missing value (NaN).
#
# ---

# %%
df.dropna(inplace=True)

# %% [markdown]
# * Handeled all the null values
#
# ---

# %%
print(df.isnull().sum())
# Out:
# name                              0
# host_id                           0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# ## 4. ***Data Visulazations and Analysis***

# %% [markdown]
# # THERE ARE SOME QUESTION TO KNOW MORE IN DETAIL ABOUT OUR PROJECT

# %% [markdown]
# #**Q1. What is the distribution airbnbs in the 5 neighbourhood groups?**
#
#
# Observing location of airbnbs over the range of latitude and longitude specified the given dataset.

# %%
#Scatter Plot to show the neighbourhood group based on Latitude and Longitude
plt.figure(figsize=(12,8))
sns.scatterplot(y=df.longitude,x=df.latitude,hue=df.neighbourhood_group)
plt.show()

# %% [markdown]
# Airbnbs are most commonly found in Brooklyn and Queens

# %% [markdown]
# **Q1**. Why did you pick the specific chart?

# %% [markdown]
# **ANS 1**. We choose the above chart to find how densely the locations of rooms are in each neighbourhood_group.

# %% [markdown]
# **Q2**. What is/are the insight(s) found from the chart?

# %% [markdown]
# **ANS 2**. From the above chart, it is visible that in Brooklyn, the premises are densely populated. In Brooklyn and Queens, rooms or hotels are present at a very minimal distance, whereas the rooms are not closely located in Staten Island and the Bronx.

# %% [markdown]
# **Q3**. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **ANS 3**. This gained insight will help for upcoming hotels in each neighbourhood_group. This also indicates that there may be tourist attractions in Queens and Brooklyn because hotels are closely located. So, this will create a positive business impact.

# %% [markdown]
# #**Q2. Which are the top 10 neighbourhood which are having maximum number of appartments for airbnb ?**

# %%
# plotting top 10 neighbourhood which are having maximum number of appartments for airbnb in the respective neighbourhood

pd.value_counts(df['neighbourhood']).groupby(df['neighbourhood_group']).head(10).plot.bar()

# %% [markdown]
# **Q1**. Why did you pick the specific chart?

# %% [markdown]
# **ANS**. We use a bar plot  to show the top 10 values and their frequencies for the "neighbourhood" column in the  dataframe.

# %% [markdown]
# **Q2**. What is/are the insight(s) found from the chart?

# %% [markdown]
# **ANS**. Williamsburg having the most number of appartments .

# %% [markdown]
# **Q3**. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **ANS**. In upper bar graph we observing that all the  apartment of  Airbnb are in West or east side... So these area showing positive impact in business..
# Because there are not so much apartment in South side of city so business is not growing in that side that  directs to negative growth

# %% [markdown]
# #**Q3.Which type of room is availble for bookings?**

# %%
#Countplot of room type
sns.countplot(df['room_type'], palette="plasma")
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Countplot of room type')
# Out:
# Text(0.5, 1.0, 'Countplot of room type')

# %% [markdown]
# **Q1**. Why did you pick the specific chart?

# %% [markdown]
# **ANS**. We use a bar plot to show the frequency count of different categories in the "room_type" column of the "df" dataframe.

# %% [markdown]
# **Q2**. What is/are the insight(s) found from the chart?

# %% [markdown]
# **ANS**. The maximum numbers of room are Entire home/Apartment and Private room.

# %% [markdown]
# **Q3**. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **ANS**. So mostly host prefer to give Entire home/Appartment or Private Rooms rather than Shared rooms.

# %% [markdown]
# #**Q4. What is the average price per night based on room type for airbnb bookings in a given locality?**

# %%
plt.figure(figsize=(12,6))

df = df[df['minimum_nights']==1]
df1 = df.groupby(['room_type','neighbourhood_group'])['price'].mean().sort_values(ascending=True)
df1.plot(kind='bar')
plt.title('Average Price for rooms in neighbourhood group')
plt.ylabel('Average Daily Price')
plt.xlabel('Neighbourhood Group')
plt.show()
print('List of Average Price per night based on the neighbourhood group')
pd.DataFrame(df1).sort_values(by='room_type')
# Out:
# List of Average Price per night based on the neighbourhood group
#                                           price
# room_type       neighbourhood_group
# Entire home/apt Queens               139.036260
#                 Bronx                141.541176
#                 Brooklyn             202.895245
#                 Staten Island        266.205128
#                 Manhattan            291.855670
# Private room    Bronx                 69.025862
#                 Staten Island         71.394366
#                 Queens                72.454958
#                 Brooklyn              81.706952
#                 Manhattan            121.469655
# Shared room     Staten Island         21.000000
#                 Bronx                 44.818182
#                 Brooklyn              60.921212
#                 Queens                68.459459
#                 Manhattan             88.462898

# %% [markdown]
# **Q1**. Why did you pick the specific chart?

# %% [markdown]
# **ANS**. A bar plot to show the average daily price for different room types in each neighborhood group

# %% [markdown]
# **Q2**. What is/are the insight(s) found from the chart?

# %% [markdown]
# **ANS**. The maximum average room price per night is in Manhattan (Entire home/ appartment).

# %% [markdown]
# **Q3**. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **ANS**. Graph indicates  avg price per night for different room types... In  different localities shared rooms and private rooms prices are very low so max booking are happening there.. that indicates that business growth...
# In other hand the prices of entire apartment/home have prices are bit higher so no. Of bookings are lower in that neighborhood so business is not growing in that neighborhoods... This is negative impact..

# %% [markdown]
# Observation: This produces a bar chart that shows the average price per night for rooms in each neighbourhood group, grouped by room type.

# %% [markdown]
# #**Q5. Which areas have least expensive rooms for airbnb bookings?**

# %%
df4 = df.dropna(subset=["price"]).groupby("neighbourhood")[["neighbourhood", "price"]].agg("mean").sort_values(by="price",
                                                                                                              ascending=True).rename(index=str, columns={"price": "Average price per night based on neighbourhood(area)"}).head(10)

df4.plot(kind='bar')
plt.show()
pd.DataFrame(df4)
# Out:
#                  Average price per night based on neighbourhood(area)
# neighbourhood
# Hunts Point                                              38.000000
# North Riverdale                                          40.000000
# Port Morris                                              41.000000
# New Dorp Beach                                           47.333333
# Bull's Head                                              48.000000
# Port Richmond                                            48.600000
# Corona                                                   48.891892
# New Brighton                                             50.000000
# Dongan Hills                                             50.333333
# Woodhaven                                                52.391304

# %% [markdown]
# **Q1**. Why did you pick the specific chart?

# %% [markdown]
# **ANS**. This bar chart shows the top 10 neighbourhoods with the lowest average prices

# %% [markdown]
# **Q2**. What is/are the insight(s) found from the chart?

# %% [markdown]
# **ANS**. Hunts point have least expensive rooms for airbnb bookings ..

# %% [markdown]
# **Q3**. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **ANS**. In above graph we monitoring that areas like Hurts Point, Port Morris have economical rooms which helps them on continuous booking which is sign of positive growth of business...
# And in the areas like Corona,Dongan Hills have expensive rooms for availability so in these localities business going towards negative growth..

# %% [markdown]
# Observation: -  This bar chart shows the top 10 neighbourhoods with the lowest average prices

# %% [markdown]
# #**Q6. Which areas have most expensive rooms for airbnb bookings?**

# %%
df5 = df.dropna(subset=["price"]).groupby("neighbourhood")[["neighbourhood", "price"]].agg("mean").sort_values(by="price",
                                                                                                              ascending=False).rename(index=str, columns={"price": "Average price per night based on neighbourhood(area)"}).head(10)

df5.plot(kind='bar')
plt.show()
pd.DataFrame(df5)
# Out:
#                    Average price per night based on neighbourhood(area)
# neighbourhood
# Randall Manor                                            1029.400000
# Battery Park City                                         563.629630
# Tribeca                                                   496.309524
# Little Italy                                              441.950000
# Greenwich Village                                         344.280000
# NoHo                                                      318.777778
# Clinton Hill                                              317.073394
# Flatiron District                                         315.400000
# West Village                                              305.440000
# Shore Acres                                               300.000000

# %% [markdown]
# **Q1**. Why did you pick the specific chart?

# %% [markdown]
# **ANS**. This bar chart shows the top 10 neighbourhoods with the Highest average prices

# %% [markdown]
# **Q2**. What is/are the insight(s) found from the chart?

# %% [markdown]
# **ANS**. Randall Manor have most expensive rooms for airbnb bookings

# %% [markdown]
# **Q3**. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **ANS**.
# The areas like Randall Manor  have higher avg. price per night
# So no. of booking are less..so business are lowered in that areas..
# And areas like west Village and shore Acres have lower avg. price per night so business is going in positive direction...

# %% [markdown]
# #**Q7. Which neighbourhood group has the most and the least number of reviews?**

# %%
fig = plt.figure(figsize=(12,4))
review_50 = df[df['number_of_reviews']>=50]
df2 = review_50['neighbourhood_group'].value_counts()
df2.plot(kind='bar',color=['r','b','g','y','m'])
plt.title('Location and Review Score(Min of 50)')
plt.ylabel('Number of Review')
plt.xlabel('Neighbourhood Group')
plt.show()
print(' Count of Review v/s neighbourhood group')
# Out:
#  Count of Review v/s neighbourhood group

# %% [markdown]
# **Q1**. Why did you pick the specific chart?

# %% [markdown]
# **ANS**. To show the number of reviews based on the neighborhood group.

# %% [markdown]
# **Q2**. What is/are the insight(s) found from the chart?

# %% [markdown]
# **ANS**. Manhattan has got the most reviews and Staten Island has the least

# %% [markdown]
# **Q3**. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **ANS**. We see that Manhattan has got the most reviews and Staten Island has the least which can be considered an important aspect for booking airbnb apart from the prices for those neighbourhood groups.

# %% [markdown]
# #**Q8. No_of_reviews v/s price**

# %%
sns.relplot(x='number_of_reviews',y='price',hue='room_type',data=df)
plt.title('no_of_reviews v/s price')
plt.show()

# %% [markdown]
# **Q1**. Why did you pick the specific chart?

# %% [markdown]
# **ANS**. We plotted this graph to just know how are the reviews based on the price.

# %% [markdown]
# **Q2**. What is/are the insight(s) found from the chart?

# %% [markdown]
# **ANS**. We observed that the listings with minimum price got more reviews than he costliest.

# %% [markdown]
# **Q3**. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **ANS**. This become quite helpful for the customers who wanted to book the costliest as well as cheapest listings available.

# %% [markdown]
# We plotted this graph to just know how are the reviews based on the price.we observed that the listings with minimum price got more reviews than he costliest.This become quite helpful for the customers who wanted to book the costliest as well as cheapest listings available.

# %% [markdown]
# #**Q9.   Which are the top 5 hosts that have  obatained heighest no. of reviews ?**

# %%
df.head()
# Out:
#                                   name  host_id neighbourhood_group  \
# 0   Clean & quiet apt home by the park     2787            Brooklyn
# 1                Skylit Midtown Castle     2845           Manhattan
# 3      Cozy Entire Floor of Brownstone     4869            Brooklyn
# 9   Cute & Cozy Lower East Side 1 bdrm     7549           Manhattan
# 17                     Chelsea Perfect    18946           Manhattan
#
#    neighbourhood  latitude  longitude        room_type  price  minimum_nights  \
# 0     Kensington  40.64749  -73.97237     Private room    149               1
# 1        Midtown  40.75362  -73.98377  Entire home/apt    225               1
# 3   Clinton Hill  40.68514  -73.95976  Entire home/apt     89               1
# 9      Chinatown  40.71344  -73.99037  Entire home/apt    150               1
# 17       Chelsea  40.74192  -73.99501     Private room    140               1
#
#     number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# ...

# %%
host_highest_df = df.groupby(['host_id'],as_index= False)['number_of_reviews'].sum().sort_values(['number_of_reviews'],ascending= False).head(5)
host_highest_df.plot(kind='pie',y= 'host_id')
plt.show()

# %% [markdown]
# **Q1**. Why did you pick the specific chart?

# %% [markdown]
# **ANS**. We use the pie chart to display the top 5 hosts with the highest "number_of_reviews" sum will be displayed in the pie chart, with each slice representing a host.

# %% [markdown]
# **Q2**. What is/are the insight(s) found from the chart?

# %% [markdown]
# **ANS**.Cozy Entire Floor of Brownstone	(4869) having the most number of reviews.

# %% [markdown]
# **Q3**. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **ANS**. Cozy in brownstone neighborhood in Brooklyn have maximum no. of reviews per month because of their services, qualities and maintenance.. so is more growing in that particular property for Airbnb
# And for property The park in  neighborhood Brooklyn have least no.of reviews per month because of their bad services, bad offerings and maintenance so business growth in negative direction for that proerty...

# %% [markdown]
# * The size of each wedge represents the fraction of the total number of reviews received by the host compared to the other hosts in the top 5.

# %% [markdown]
# #**Q10. Which neighbourhood group is the most busy in terms of bookings?**

# %%
plt.figure(figsize=(10,10))
ax = sns.boxplot(data=df, x='neighbourhood_group',y='availability_365',palette='plasma')

# %% [markdown]
# **Q1**. Why did you pick the specific chart?

# %% [markdown]
# **ANS**. A box plot to visualize the distribution of the "availability_365" column grouped by the "neighbourhood_group" column.

# %% [markdown]
# **Q2**. What is/are the insight(s) found from the chart?

# %% [markdown]
# **ANS**. It can be seen that the hotels in Staten Island have the highest availabilty around the year

# %% [markdown]
# **Q3**. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **ANS**. As we observing that the places in Brooklyn neighbor hood have minimum no. of  free days in availability... So business in that area is growing for AIRBNB...
# And for neighborhood like Staten Island have maximum no. of free days in availability so.. growth of business is in negative direction in that neighborhood

# %% [markdown]
# #**Q11.Different Count of room type on the basis of Neighbourhood group.**

# %%
plt.figure(figsize=(15,10))
plt.title("Room Type with respect to neighbourhood")
sns.countplot(df.neighbourhood_group,hue=df.room_type, palette="deep")
plt.show()

# %% [markdown]
# **Q1**. Why did you pick the specific chart?

# %% [markdown]
# **ANS**. A bar plot that displays the count of each room type in each neighborhood group.

# %% [markdown]
# **Q2**. What is/are the insight(s) found from the chart?

# %% [markdown]
# **ANS**. The graph shows that Private rooms are most listed in Brooklyn that is nearly 10000, Manhattan neighbourhood clearly dominates in listing of Entire Home type and listing of Shared rooms are very less compared to other room type but Manhattan and Brooklyn covers the most numbers around 500 and 600 respectively.

# %% [markdown]
# **Q3**. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **ANS**. In upper graph we discovering that in all 5 neighborhood of city maximum no. of room either private or entire apartment so business is growing in that neighborhood...
# Because a least no. of sharing room available in all neighborhood that indicates towards a negative effect on business growth..

# %% [markdown]
# #**Q.12 How many Hosts are listed in all neighbourhood group on the basis of Host_Id.**

# %%
colors = sns.color_palette('cubehelix')
Popular_host_areawise = df[['host_id','neighbourhood_group']].groupby(['neighbourhood_group']).nunique('host_id').sort_values('host_id',ascending=False)
Popular_host_areawise.plot(kind='pie',subplots=True,radius=2,autopct='%.0f%%',explode=[0.1,0.1,0.1,0.1,0.4])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f8b19e05c70>],
#       dtype=object)

# %% [markdown]
# **Q1**. Why did you pick the specific chart?

# %% [markdown]
# **ANS**. A pie chart of the number of unique host IDs per neighborhood group.

# %% [markdown]
# **Q2**. What is/are the insight(s) found from the chart?

# %% [markdown]
# **ANS**. We can see that 44% hosts are listed in Manhattan followed by 43% in Brooklyn and least in Staten Island with 1%

# %% [markdown]
# **Q3**. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **ANS**. In upper pie chart we noticed that max no. of hosts are in Brooklyn, Manhattan and Queens area.... So business is growing in that neighborhoods.
# In Bronx and Staten Island the no. of hosts are very less.. so there is negative growth in the business....

# %% [markdown]
# # Correlation Heatmap

# %%
corr_df=df.corr()
sns.heatmap(corr_df,annot=True)

# %% [markdown]
# **Q1**. Why did you pick the specific chart?

# %% [markdown]
# **ANS**. Heatmap is plotted to find the correlation between different features. This helps in feature engineering and removing multicollinearity between the features. In the heatmap, a feature's correlation is depicted concerning each numeric feature present in the dataset. Here, -1 shows a highly negative correlation whereas 1 shows a highly positive correlation.

# %% [markdown]
# **Q2**. What is/are the insight(s) found from the chart?

# %% [markdown]
# **ANS**. In the above heatmap, it is depicted that price and price_for_a_night are highly correlated. And this collinearity should be removed or minimized using feature engineering because these two columns are highly correlated. From the heatmap, it is clear that all features are not correlated or very minute correlations between the variables.

# %% [markdown]
# # Chart - Pair Plot

# %%
pair_df=df.drop(['longitude','latitude'], axis=1)
sns.pairplot(pair_df)

# %% [markdown]
# The above code generates a pairplot that shows the relationship between multiple variables in the dataframe pair_df (which is created by dropping the columns 'longitude' and 'latitude' from the original dataframe df). The pairplot shows the distribution of each variable on the diagonal and the relationship between each pair of variables on the off-diagonal plots. This type of plot is useful for exploring the relationship between variables in a dataset and for identifying potential outliers or trends.

# %% [markdown]
# # 5. Solution to Business Objective

# %% [markdown]
# . Periodically look at the customer reviews so that based on the review host can upgrade the rooms.
#
# . The host must follow the business pattern of top active hosts.
#
# . The host must focus on the Private and Entire home/Apt because its demand is high.
#
# . The Premises should be in the Average price range of each room type in the respected neighborhood group.
#
# . By keeping eye on the nearest host premises whether they giving any offers or not to visitors to increase their bookings.
#
# . By keeping an eye on the location of premises that in which location demand for which room types is high.
#
# . The new host must open his premises in the Manhattan neighborhood group       because in manhattan the bookings are and most of the revenue of Airbnb is generated from Manhattan as compared to other neighborhood groups.
#
# . It can be the best opportunity for the host to add his premises to the Staten Island neighborhood group because here premises are low in number and there will be less competition between the hosts.
#
# . They have to maintain their rating for this, along with the price the will    also have to provide great service to the customer
#
# . Stay competitive and updated

# %% [markdown]
# ## **6. Conclusion**

# %% [markdown]
# **By doing exploratory data analysis on the airbnb dataset we have concluded that the most important aspects for bookings are as follows :**
#
# *	The locality and availability
# *	The price and reviews of the rooms in the locality
# * The host of these airbnbs
#
# We tried to observe airbnbs distribution in the areas as well as price trends based on room types,reviews and locality .
# It was also possible to do a comparative analysis of how Airbnb affecting the neighbourhoods based on prices and reviews.
# However, It would have been more helpful if actual reviews had been provided of the booked rooms.
